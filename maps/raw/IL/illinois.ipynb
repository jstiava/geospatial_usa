# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

TARGET_CRS = "EPSG:5070"

# %%
from pathlib import Path

folder = Path("../historical_districts_by_state/IL")

Illinois = {}

for file in folder.iterdir():
    Illinois[file.name] = gpd.read_file(file).to_crs(TARGET_CRS)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

Illinois['IL_CD_2021_30.geojson'].plot(
    ax=ax,
    edgecolor='black',
    linewidth=0.5,
    label="IL-8",
)

# plt.legend()
# plt.title("Precincts by Overlapping City")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig, ax = plt.subplots(figsize=(10, 10))
#       3 Illinois['IL_CD_2021_30.geojson'].plot(
#       4     ax=ax,
#       5     edgecolor='black',
#       6     linewidth=0.5,
#       7     label="IL-8",
#       8 )
#      10 # plt.legend()
#      11 # plt.title("Precincts by Overlapping City")
#
# NameError: name 'plt' is not defined

# %%
Illinois
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Illinois
#
# NameError: name 'Illinois' is not defined
