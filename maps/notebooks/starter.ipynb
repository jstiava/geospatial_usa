# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

TARGET_CRS = "EPSG:5070"

# %%
states = gpd.read_file("../raw/mainland_usa_states.geojson").to_crs(TARGET_CRS)
school_board_districts = gpd.read_file("../raw/chicago_school_board_districts/districts2026/districts2026.shp").to_crs("EPSG:5070")
school_board_districts_2024 = gpd.read_file("../raw/chicago_school_board_districts/districts2024/districts2024.shp").to_crs("EPSG:5070")
chicago_wards_22 = gpd.read_file("../raw/chicago_wards/wards2022/wards2022.shp").to_crs(TARGET_CRS)
chicago_wards_12 = gpd.read_file("../raw/chicago_wards/wards2012.geojson").to_crs(TARGET_CRS)
chicago_wards_02 = gpd.read_file("../raw/chicago_wards/wards2002.geojson").to_crs(TARGET_CRS)

# %%
il_cd_22 = gpd.read_file("congressional_districts/tl_2022_17_cd118/tl_2022_17_cd118.shp").to_crs(TARGET_CRS)
il_cd_12 = gpd.read_file("congressional_districts/tl_2012_17_cd/tl_2012_17_cd.shp").to_crs(TARGET_CRS)
il_cd_02 = gpd.read_file("congressional_districts/tl_2002_17_cd/tl_2002_17_cd.shp").to_crs(TARGET_CRS)

# %%
counties = gpd.read_file("counties/counties.shp").to_crs(TARGET_CRS)

# %%
chicago_community_areas.to_file("../raw/chicago_community_areas.geojson")

# %%
wards1992 = gpd.read_file("ward1992/ward1992.shp").to_crs(TARGET_CRS)

# %%
wards1992.to_file("../raw/ChicagoWards_1992-2000.geojson")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
fig, ax = plt.subplots(figsize=(10, 10))

wards1992.plot(
    ax=ax,
    edgecolor='black',
    linewidth=0.5,
    label="IL-8",
)

# plt.legend()
# plt.title("Precincts by Overlapping City")
plt.show()
